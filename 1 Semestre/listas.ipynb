# %%
#declaração de listas
listas = [] # Por boa prática deixar nome de lista em no plural

# %%
listas = ["O carro", "peixe", 123, 111]

print(len(listas))
print(listas*3)
# Out:
# 4
# ['O carro', 'peixe', 123, 111, 'O carro', 'peixe', 123, 111, 'O carro', 'peixe', 123, 111]

# %%
livros = ['Java', 'SqlServer', 'Delphi', 'Pyhon']
livros.append('Android')
livros.insert(0,'Oracle')
print(livros)
livros.pop(5)
# Out:
# ['Oracle', 'Java', 'SqlServer', 'Delphi', 'Pyhon', 'Android']

# %%
lista = []
for x in range(5):
    n = int(input("Digite um número inteiro"))
    lista.append(n)
    lista.sort()
    print(lista)
# Out:
# Digite um número inteiro50
# [50]
# Digite um número inteiro40
# [40, 50]
# Digite um número inteiro56
# [40, 50, 56]
# Digite um número inteiro23
# [23, 40, 50, 56]
# Digite um número inteiro89
# [23, 40, 50, 56, 89]
